# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()

model = ChatOpenAI()

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'I. Introduction\n    A. Overview of AI and its growing significance in India\n    B. Brief history of AI development in India\n    C. Purpose of the blog post\n\nII. Current state of AI in India\n    A. Adoption of AI technologies by Indian businesses\n    B. Government initiatives and policies promoting AI research and development\n    C. Key players in the AI industry in India\n\nIII. Applications of AI in India\n    A. Healthcare\n        1. AI-powered diagnosis and treatment\n        2. Remote healthcare services\n    B. Finance\n        1. AI-driven personalized banking services\n        2. Fraud detection and prevention\n    C. Agriculture\n        1. Precision farming using AI\n        2. Crop monitoring and yield prediction\n    D. Education\n        1. AI-based personalized learning platforms\n        2. Virtual classrooms and tutoring services\n\nIV. Challenges and opportunities in the AI sector in India\n    A. Skilled workforce shortage\n    B. Data privacy and security concerns\n    C. Ethical implications of AI technologies\n    D. Opportunities for collaboration and innovation\n\nV. Future outlook for AI in India\n    A. Projected growth of the AI industry in India\n    B. Potential impact of AI on the Indian economy\n    C. Opportunities for startups and entrepreneurs in the AI sector\n    D. Recommendations for policymakers and stakeholders\n\nVI. Conclusion\n    A. Recap of key points discussed in the blog post\n    B. Final thoughts on the rise of AI in India\n    C. Call to action for readers to continue following developments in the AI sector in India.', 'content': 'I. Introduction\n\nA. Artificial Intelligence (AI) is a rapidly evolving field that has the potential to revolutionize various industries and sectors. In recent years, AI has gained significant traction in India, with businesses and government organizations increasingly adopting AI technologies to streamline operations, enhance efficiency, and drive innovation.\n\nB. The history of AI development in India dates back to the 1980s when the Indian government launched the AI Project, which aimed to promote research and development in AI. Since then, India has made significant strides in AI research and innovation, with a growing number of startups and companies focusing on AI-based solutions.\n\nC. The purpose of this blog post is to explore the rise of AI in India, discuss the current state of AI adoption, highlight key applications of AI in various sectors, examine the challenges and opportunities in the AI sector, and provide insights on the future outlook for AI in India.\n\nII. Current state of AI in India\n\nA. Indian businesses across various industries such as healthcare, finance, agriculture, education, and more are increasingly adopting AI technologies to improve processes, enhance decision-making, and deliver personalized services to customers.\n\nB. The Indian government has also recognized the potential of AI and has introduced several initiatives and policies to promote AI research and development. For instance, the National AI Portal was launched to facilitate collaboration between academia, industry, and government in the field of AI.\n\nC. Key players in the AI industry in India include established companies like Infosys, Wipro, and Tata Consultancy Services, as well as startups such as Niki.ai, SigTuple, and Locus.sh, which are at the forefront of AI innovation in the country.\n\nIII. Applications of AI in India\n\nA. In healthcare, AI-powered solutions are being used for diagnosis, treatment, remote healthcare services, and personalized care, leading to improved patient outcomes and reducing healthcare costs.\n\nB. In finance, AI technologies are revolutionizing the industry by providing personalized banking services, enhancing fraud detection and prevention, and optimizing customer service.\n\nC. In agriculture, AI is enabling precision farming, crop monitoring, yield prediction, and  ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Overview of AI and its growing significance in India
#     B. Brief history of AI development in India
#     C. Purpose of the blog post
#
# II. Current state of AI in India
#     A. Adoption of AI technologies by Indian businesses
#     B. Government initiatives and policies promoting AI research and development
#     C. Key players in the AI industry in India
#
# III. Applications of AI in India
#     A. Healthcare
#         1. AI-powered diagnosis and treatment
#         2. Remote healthcare services
#     B. Finance
#         1. AI-driven personalized banking services
#         2. Fraud detection and prevention
#     C. Agriculture
#         1. Precision farming using AI
#         2. Crop monitoring and yield prediction
#     D. Education
#         1. AI-based personalized learning platforms
#         2. Virtual classrooms and tutoring services
#
# IV. Challenges and opportunities in the AI sector in India
#     A. Skilled workforce shortage
#     B. Data privacy and security concerns
#     C. Ethical implications of AI technologies
#     D. Opportunities for collaboration and innovation
#
# V. Future outlook for AI in India
#     A. Projected growth of the AI industry in India
#     B. Potential impact of AI on the Indian economy
#     C. Opportunities for startups and entrepreneurs in the AI sector
#     D. Recommendations for policymakers and stakeholders
#
# VI. Conclusion
#     A. Recap of key points discussed in the blog post
#     B. Final thoughts on the rise of AI in India
#     C. Call to action for readers to continue following developments in the AI sector in India.

# %%
print(final_state['content'])
# Out:
# I. Introduction
#
# A. Artificial Intelligence (AI) is a rapidly evolving field that has the potential to revolutionize various industries and sectors. In recent years, AI has gained significant traction in India, with businesses and government organizations increasingly adopting AI technologies to streamline operations, enhance efficiency, and drive innovation.
#
# B. The history of AI development in India dates back to the 1980s when the Indian government launched the AI Project, which aimed to promote research and development in AI. Since then, India has made significant strides in AI research and innovation, with a growing number of startups and companies focusing on AI-based solutions.
#
# C. The purpose of this blog post is to explore the rise of AI in India, discuss the current state of AI adoption, highlight key applications of AI in various sectors, examine the challenges and opportunities in the AI sector, and provide insights on the future outlook for AI in India.
#
# II. Current state of AI in India
#
# A. Indian businesses across various industries such as healthcare, finance, agriculture, education, and more are increasingly adopting AI technologies to improve processes, enhance decision-making, and deliver personalized services to customers.
#
# B. The Indian government has also recognized the potential of AI and has introduced several initiatives and policies to promote AI research and development. For instance, the National AI Portal was launched to facilitate collaboration between academia, industry, and government in the field of AI.
#
# C. Key players in the AI industry in India include established companies like Infosys, Wipro, and Tata Consultancy Services, as well as startups such as Niki.ai, SigTuple, and Locus.sh, which are at the forefront of AI innovation in the country.
#
# III. Applications of AI in India
#
# A. In healthcare, AI-powered solutions are being used for diagnosis, treatment, remote healthcare services, and personalized care, leading to improved patient outcomes and reducing healthcare costs.
#
# B. In finance, AI technologies are revolutionizing the industry by providing personalized banking services, enhancing fraud detection and prevention, and optimizing customer service.
#
# C. In agriculture, AI is enabling precision farming, crop monitoring, yield prediction, and resource optimization, helping farmers make informed decisions and improve productivity.
#
# D. In education, AI-based platforms are facilitating personalized learning, virtual classrooms, tutoring services, and adaptive learning techniques, making education more accessible and effective.
#
# IV. Challenges and opportunities in the AI sector in India
#
# A. One of the key challenges facing the AI sector in India is the shortage of skilled workforce with expertise in AI technologies, machine learning, and data science.
#
# B. Data privacy and security concerns are also significant challenges, as the use of AI involves handling sensitive personal and business data, raising questions about data protection and compliance.
#
# C. The ethical implications of AI technologies such as bias, transparency, and accountability are important considerations that need to be addressed to ensure responsible and ethical AI development and deployment.
#
# D. Despite these challenges, there are ample opportunities for collaboration, innovation, and growth in the AI sector in India, with the potential to drive economic development and create new avenues for entrepreneurship and job creation.
#
# V. Future outlook for AI in India
#
# A. The AI industry in India is expected to experience significant growth in the coming years, with projections indicating that AI could contribute significantly to the Indian economy and transform various sectors.
#
# B. The potential impact of AI on the Indian economy is substantial, with AI technologies expected to drive productivity, innovation, and competitiveness, leading to economic growth and job creation.
#
# C. There are immense opportunities for startups and entrepreneurs in the AI sector, with the availability of funding, mentorship, resources, and a conducive ecosystem that supports innovation and entrepreneurship.
#
# D. Policymakers and stakeholders in India need to focus on creating a supportive regulatory environment, investing in skills development, fostering collaboration between academia, industry, and government, and promoting ethical AI practices to ensure sustainable growth and responsible deployment of AI technologies.
#
# VI. Conclusion
#
# A. In conclusion, the rise of AI in India presents numerous opportunities for innovation, economic growth, and societal transformation. By leveraging AI technologies effectively, India can address key challenges, drive productivity, enhance decision-making, and improve the quality of life for its citizens.
#
# B. The future of AI in India looks promising, with the potential to revolutionize various sectors and make India a global hub for AI research, innovation, and entrepreneurship.
#
# C. As readers, it is essential to stay informed about developments in the AI sector in India, engage with key stakeholders, and actively contribute to the growth and advancement of AI technologies in the country. Let us embrace the rise of AI in India and work towards building a future that is powered by innovation, collaboration, and ethical AI practices.
